# %% [markdown]
# | Project name   |  Medidor UV |
# |:----------|:-------------|
# | **Autor(S)**| T025605, Gustavo Salazar<br>T033167, Rodolfo Macías |
# | **Editor**|Dr. Adán Hirales Carbajal|
# | **Last update** | 11 de Septiembre, 2022|

# %% [markdown]
# ### <span style="color:blue">Problem statement</span>
#
# La resolución de laberintos y encontrar la ruta óptima han sido unos de los problemas más comunes en las áreas de robótica y optimización. Se busca diseñar e implementar un algoritmo que pueda resolverlos de manera rápida en un robot autónomo y que posiblemente pueda llegar a participar en competiciones de tal índole.
#
# El proyecto usa algoritmos de busqueda y solución para que nuestro microcontrolador pueda moverse
#
# Objetivos:
# Implementación y diseño de un algoritmo a un robot autónomo para la resolución de un laberinto de paredes.
# Implementación de un sistema autónomo para el robot en un sistema embebido (Adecuado a la normas IEEE para las competencias).
# Diseñar un robot con especificaciones de las competencias de micromouse.

# %% [markdown]
# ### <span style="color:blue">Hardware requirements</span>
#
#
# |Component|Quantity|Characteristics|Component|
# |:---|:---|:-----|:---:|
# |STM32 F103C8T6|1| Development board|<img src="img_shift_register/stm32.jpeg" alt="SIPO" width="150" eight="150">|
# |PCB |1| For connections |<img src="img_shift_register/sipo_pinout.png" alt="SIPO" width="150" eight="150">|
# |Motores con Encoder | 1|<img src="img_shift_register/piso_pinout.png" alt="PISO" width="200" height="200">|
# |Sensores con IR | 1|
# |Step-ups Voltage Converter| 4|

# %% [markdown]
# ### <span style="color:blue">hardware schematic</span>
#
# <center>
# <img class="large-image" width="350" height="350" src="uMouse_v2.jpeg" />
# </center>
