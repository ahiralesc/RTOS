# %% [markdown]
# | Project name   |  Medidor UV |
# |:----------|:-------------|
# | **Autor(S)**| T29902 Gerardo Meneses, T031893 Andrea Sanchez |
# | **Editor**|Dr. Adán Hirales Carbajal|
# | **Last update** |  |

# %% [markdown]
# ### <span style="color:blue">Problem statement</span>
# This projec involves playing music through two speakers. That is achived using two PWM pins and manipulating the frecuency in order to play different tones. The output of those pins are connected to an ammplifier which then leads to the speakers

# %% [markdown]
# ### <span style="color:blue">Hardware requirements</span>
#
#
# |Component|Quantity|Characteristics|Component|
# |:---|:---|:-----|:---:|
# |STM32 F767ZI|1| Proporciona a los usuarios una forma asequible y flexible de probar nuevos conceptos y desarrollar prototipos con el microcontrolador STM32, escogiendo distintas combinaciones de rendimiento, consumo de energía y funciones.|<img src="https://external-content.duckduckgo.com/iu/?u=https%3A%2F%2Fwww.carminenoviello.com%2Fwp-content%2Fuploads%2F2015%2F12%2Fnucleo_144_large-2.jpg&f=1&nofb=1&ipt=ff28004393d2d554a69a3201244227f8eafa07774240333c56d7ea5d160024c5&ipo=images" alt="SIPO" width="150" eight="150">|
# |KY-037|1| PAM8403 módulo Super Mini amplificador digital Junta 2 3 W clase D potencia amplificador Junta eficiente 2.5 a 5 V entrada. |<img src="https://m.media-amazon.com/images/I/61jVo-3yUNL._AC_SX466_.jpg" alt="SIPO" width="150" eight="150">|
# |ESP8266 ESP-01| 2|  Altavoz magnético interno redondo de carcasa de metal, 2 W, 8 ohmios |<img src="https://m.media-amazon.com/images/I/61GIyMKomXL._SX522_.jpg" alt="PISO" width="200" height="200">

# %% [markdown]
# Esquematico Proyecto

# %% [markdown]
# ![Esquematico.PNG](data:image/png;base64,...)

# %% [markdown]
# ### Static Diagram

# %% [markdown]
# ![stastic diagram](https://github.com/MenesesGHZ/RTOS/blob/main/F413ZHT6_Lucas/img/Coolaborative%20Diagram.drawio.png?raw=true)

# %% [markdown]
# ### Colaboritve Diagram

# %% [markdown]
# ![stastic diagram](https://github.com/MenesesGHZ/RTOS/blob/main/F413ZHT6_Lucas/img/StaticModel.drawio%20.png?raw=true)
